# %% [markdown]
# # [Module 8] Recommendation API 호출

# %% [markdown]
# # 0. 환경 설정

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import boto3
import json
import numpy as np
import pandas as pd
import time
from datetime import datetime

# %% [markdown]
# 다음으로 여러분의 환경이 Amazon Personalize와 성공적으로 통신할 수 있는지 확인해야 합니다.

# %%
# Configure the SDK to Personalize:
personalize = boto3.client('personalize')
personalize_runtime = boto3.client('personalize-runtime')

# %% [markdown]
# 아래 코드 셀은 이전 notebook에서 저장했던 공유 변수들을 불러옵니다.

# %%
# %store -r

# %% [markdown]
# # 1. 아이템 테이터 로딩
#
# - 추천 결과의 ITEM_ID 의 상세 내용을 확인하기 위해서 로딩 함.

# %%
from src.p_utils import get_item_list_details

items_df = pd.read_csv(base_items_filename)

items_df.head()
# Out:
#                                 ITEM_ID                      NAME  \
# 0  e1669081-8ffc-4dec-97a6-e9176d7f6651         Sans Pareil Scarf
# 1  cfafd627-7d6b-43a5-be05-4c7937be417d                Chef Knife
# 2  6e6ad102-7510-4a02-b8ce-5a0cd6f431d1          Gainsboro Jacket
# 3  49b89871-5fe7-4898-b99d-953e15fb42b2  High Definition Speakers
# 4  5cb18925-3a3c-4867-8f1c-46efd7eba067            Spiffy Sandals
#
#    CATEGORY_L1    STYLE                                PRODUCT_DESCRIPTION  \
# 0      apparel    scarf                        Sans pareil scarf for women
# 1   housewares  kitchen                       A must-have for your kitchen
# 2      apparel   jacket  This gainsboro jacket for women is perfect for...
# 3  electronics  speaker  High definition speakers to fill the house wit...
# 4     footwear  sandals  This spiffy pair of sandals for woman is perfe...
#
#     PRICE
# 0  124.99
# 1   57.99
# 2  133.99
# 3  196.99
# 4    9.99

# %% [markdown]
# # 2. Recommendation API 호출
#
# - 두 명의 user_id (에: 1, 100) 에 대해서 추천 결과를 얻음.

# %% [markdown]
# ### USER-PERSONALIZATION 솔루션 추천 : user_id = 1

# %%
user_id = 1

get_recommendations_response = personalize_runtime.get_recommendations(
    campaignArn = base_campaign_arn,
    userId = str(user_id),
    numResults = 10
)


items_list = []    
for item in get_recommendations_response['itemList']:
    items_list.append(item['itemId'])   
    # print (item['itemId'])
    
print("-------------------")    
print("user_id: ", user_id)    
print("-------------------")    
print("Solution Recommendation")
get_item_list_details(items_df, items_list)  # 유의: 기존의 추천 순서와 리턴의 값이 순서가 다름
# Out:
# -------------------
# user_id:  1
# -------------------
# Solution Recommendation
#                                 ITEM_ID                       NAME  \
# 0  29359485-1173-4a37-9bb7-6065c58a4f9e         White Office Chair
# 1  48941756-e6c4-4b45-a869-c4f33daccdeb            Yellow Armchair
# 2  a87aa681-f9bb-48a7-9d79-4aafc7b6d6db    Light Gray Accent Table
# 3  328a7f6b-238d-4165-9949-5e0aa70b7200    Light Gray Dining Chair
# 4  3293c333-10c8-4837-a07d-d8cd9e0f9bf8       Saddle Brown Dresser
# 5  e9c299d3-f657-448f-85cd-8cda432a59b8    Dark Slate Gray Dresser
# 6  489dee3d-6abf-4470-bb94-8b9c0d12f18e  Saddle Brown Office Chair
# 7  d0cb72b7-f819-432e-8492-9bc8b7692043        Sienna Office Chair
# 8  d725a542-ddaf-4e1c-a2fb-10628a6e1407         Black Office Chair
# 9  95677239-43cc-44e4-a97f-4a9c072210ae         Gainsboro Armchair
#
#   CATEGORY_L1     STYLE                                PRODUCT_DESCRIPTION  \
# 0   furniture    chairs                  Ideal white chair for your office
# 1   furniture    chairs                 Relax in this nice yellow armchair
# 2   furniture    tables   Hip light gray accent table to enhance your room
# 3   furniture    chairs  Unparalleled light gray chair for any dining room
# 4   furniture  dressers  This unequaled dresser has lots of drawers to ...
# 5   furniture  dressers  Unsurpassed dark slate gray dresser with three...
# 6   furniture    chairs  Increase your productivity with this nice sadd...
# 7   furniture    chairs  Increase your productivity with this soft sien...
# 8   furniture    chairs  Increase your productivity with this nice blac...
# 9   furniture    chairs             Swanky gainsboro armchair for any room
#
#     PRICE
# 0  182.99
# 1  111.99
# 2  276.99
# 3  120.99
# 4  120.99
# 5  125.99
# 6  210.99
# 7  232.99
# 8  112.99
# 9  211.99

# %% [markdown]
# ### USER-PERSONALIZATION 솔루션 추천 : user_id = 100

# %%
user_id = 100

get_recommendations_response = personalize_runtime.get_recommendations(
    campaignArn = base_campaign_arn,
    userId = str(user_id),
    numResults = 10
)


items_list = []    
for item in get_recommendations_response['itemList']:
    items_list.append(item['itemId'])   
    # print (item['itemId'])
    
print("-------------------")    
print("user_id: ", user_id)    
print("-------------------")    
print("Solution Recommendation")
get_item_list_details(items_df, items_list)  # 유의: 기존의 추천 순서와 리턴의 값이 순서가 다름
# Out:
# -------------------
# user_id:  100
# -------------------
# Solution Recommendation
#                                 ITEM_ID                 NAME  CATEGORY_L1  \
# 0  c86e8896-b9e0-4121-a3e4-25dfb435e2f1             Keyboard  instruments
# 1  cb7d77fe-a42a-41e3-be86-c54c0aa4b432             Drum Set  instruments
# 2  e09d3267-1a87-4518-9fa7-fa9ed847c80d  Accurate Microphone  instruments
# 3  203b54b8-9ffd-4512-9b2b-aab6f47c5c42        Acoustic Bass  instruments
# 4  a2b531d1-c2a8-474a-bef4-1cde8a050e1a             Keyboard  instruments
# 5  bec6d82b-b23d-45d9-91c9-6693d4585e68        Electric Bass  instruments
# 6  67438f99-65f6-4788-827c-0e69538f29c6      Electric Guitar  instruments
# 7  a54fbc82-c85d-4d21-b907-e8cdbbff69d2        Acoustic Bass  instruments
# 8  e4f7e8b7-2c26-4939-9efd-b10f53a2ed04             Keyboard  instruments
# 9  468a8075-7b32-47dc-b5dd-1ecb3a5d26f4      Electric Guitar  instruments
#
#         STYLE                                PRODUCT_DESCRIPTION   PRICE
# 0        keys  This keyboard will delight the most demanding ...  390.99
# 1  percussion  This drum set is perfect for amateur and profe...  253.99
# 2  microphone  This accurate microphone can be relied upon in...  499.99
# 3     strings  This acoustic bass will delight the most deman...  463.99
# 4        keys  This keyboard will delight the most demanding ...  320.99
# 5     strings  This electric bass is perfect for amateur and ...  104.99
# 6     strings  This electric guitar is perfect for amateur an...  360.99
# 7     strings  This acoustic bass will delight the most deman...  221.99
# 8        keys  This keyboard will delight the most demanding ...  321.99
# 9     strings  This electric guitar will delight the most dem...  249.99
