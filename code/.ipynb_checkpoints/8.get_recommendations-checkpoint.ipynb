# %% [markdown]
# # [Module 8] Recommendation API 호출

# %% [markdown]
# # 0. 환경 설정

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import boto3
import json
import numpy as np
import pandas as pd
import time
from datetime import datetime

# %% [markdown]
# 다음으로 여러분의 환경이 Amazon Personalize와 성공적으로 통신할 수 있는지 확인해야 합니다.

# %%
# Configure the SDK to Personalize:
personalize = boto3.client('personalize')
personalize_runtime = boto3.client('personalize-runtime')

# %% [markdown]
# 아래 코드 셀은 이전 notebook에서 저장했던 공유 변수들을 불러옵니다.

# %%
# %store -r

# %% [markdown]
# # 1. 아이템 테이터 로딩
#
# - 추천 결과의 ITEM_ID 의 상세 내용을 확인하기 위해서 로딩 함.

# %%
from src.p_utils import get_item_list_details

items_df = pd.read_csv(base_items_filename)

items_df.head()
# Out:
#                                 ITEM_ID                      NAME  \
# 0  e1669081-8ffc-4dec-97a6-e9176d7f6651         Sans Pareil Scarf
# 1  cfafd627-7d6b-43a5-be05-4c7937be417d                Chef Knife
# 2  6e6ad102-7510-4a02-b8ce-5a0cd6f431d1          Gainsboro Jacket
# 3  49b89871-5fe7-4898-b99d-953e15fb42b2  High Definition Speakers
# 4  5cb18925-3a3c-4867-8f1c-46efd7eba067            Spiffy Sandals
#
#    CATEGORY_L1    STYLE                                PRODUCT_DESCRIPTION  \
# 0      apparel    scarf                        Sans pareil scarf for women
# 1   housewares  kitchen                       A must-have for your kitchen
# 2      apparel   jacket  This gainsboro jacket for women is perfect for...
# 3  electronics  speaker  High definition speakers to fill the house wit...
# 4     footwear  sandals  This spiffy pair of sandals for woman is perfe...
#
#     PRICE
# 0  124.99
# 1   57.99
# 2  133.99
# 3  196.99
# 4    9.99

# %% [markdown]
# # 2. Recommendation API 호출
#
# - 두 명의 user_id (에: 1, 100) 에 대해서 추천 결과를 얻음.

# %% [markdown]
# ### 사용자 과거 Interactions 확인 (user_id = 1)

# %%
user_id = 1


def get_user_interaction_history(interactions_df, items_df, user_id):
    # 특정 사용자의 상호작용 기록 필터링
    user_interactions = interactions_df[interactions_df['USER_ID'] == user_id]
    
    # 시간순으로 정렬
    if 'TIMESTAMP' in user_interactions.columns:
        user_interactions = user_interactions.sort_values('TIMESTAMP', ascending=False)
    
    print("-------------------")    
    print(f"User {user_id}의 상호작용 기록")
    print("-------------------")
    
    if len(user_interactions) == 0:
        print("상호작용 기록이 없습니다.")
        return
    
    # 각 상호작용에 대해 아이템 정보 출력
    for _, row in user_interactions.iterrows():
        print("-------------------")
        # items_df에서 해당 아이템 정보 찾기
        item_info = items_df[items_df['ITEM_ID'] == row['ITEM_ID']]
        
        if not item_info.empty:
            print(f"아이템명: {item_info['NAME'].iloc[0]}")
            print(f"카테고리: {item_info['CATEGORY_L1'].iloc[0]}")
            print(f"스타일: {item_info['STYLE'].iloc[0]}")
            print(f"가격: ${item_info['PRICE'].iloc[0]}")
        
        print(f"이벤트 타입: {row['EVENT_TYPE']}")
        print(f"시간: {row['TIMESTAMP']}")
        print(f"Item ID: {row['ITEM_ID']}")



# 1. 현재 추천 결과 출력
print("현재 추천 결과:")
get_recommendations_response = personalize_runtime.get_recommendations(
    campaignArn = base_campaign_arn,
    userId = str(user_id),
    numResults = 10
)

items_list = []    
for item in get_recommendations_response['itemList']:
    items_list.append(item['itemId'])   

print("-------------------")    
print("user_id: ", user_id)    
print("-------------------")    
print("Solution Recommendation")
get_item_list_details(items_df, items_list)

# 2. 과거 상호작용 기록 출력
print("\n과거 상호작용 기록:")
get_user_interaction_history(interactions_df, items_df, user_id)
# Out:
# 현재 추천 결과:
# -------------------
# user_id:  1
# -------------------
# Solution Recommendation
#
# 과거 상호작용 기록:
# -------------------
# User 1의 상호작용 기록
# -------------------
# -------------------
# 아이템명: Saddle Brown Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $210.99
# 이벤트 타입: View
# 시간: 1598117332
# Item ID: 489dee3d-6abf-4470-bb94-8b9c0d12f18e
# -------------------
# 아이템명: Saddle Brown Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $210.99
# 이벤트 타입: View
# 시간: 1598117332
# Item ID: 489dee3d-6abf-4470-bb94-8b9c0d12f18e
# -------------------
# 아이템명: Table Lamp
# 카테고리: homedecor
# 스타일: lighting
# 가격: $26.99
# 이벤트 타입: View
# 시간: 1597970177
# Item ID: 5763e87b-9b9c-456d-8986-1f1e34fa9318
# -------------------
# 아이템명: Table Lamp
# 카테고리: homedecor
# 스타일: lighting
# 가격: $26.99
# 이벤트 타입: View
# 시간: 1597970177
# Item ID: 5763e87b-9b9c-456d-8986-1f1e34fa9318
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1597923421
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1597923421
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1597923421
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Easter Basket
# 카테고리: homedecor
# 스타일: decorative
# 가격: $18.99
# 이벤트 타입: View
# 시간: 1597918775
# Item ID: 6f3a269d-f83f-4659-a28e-7ddbbcea4eab
# -------------------
# 아이템명: Easter Basket
# 카테고리: homedecor
# 스타일: decorative
# 가격: $18.99
# 이벤트 타입: View
# 시간: 1597918775
# Item ID: 6f3a269d-f83f-4659-a28e-7ddbbcea4eab
# -------------------
# 아이템명: Easter Basket
# 카테고리: homedecor
# 스타일: decorative
# 가격: $18.99
# 이벤트 타입: View
# 시간: 1597918775
# Item ID: 6f3a269d-f83f-4659-a28e-7ddbbcea4eab
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1597697421
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1597697421
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1597697421
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: White Dining Table
# 카테고리: furniture
# 스타일: tables
# 가격: $225.99
# 이벤트 타입: View
# 시간: 1597609245
# Item ID: be14695b-f8cb-46b8-aecd-ef28f0218514
# -------------------
# 아이템명: White Dining Table
# 카테고리: furniture
# 스타일: tables
# 가격: $225.99
# 이벤트 타입: View
# 시간: 1597609245
# Item ID: be14695b-f8cb-46b8-aecd-ef28f0218514
# -------------------
# 아이템명: White Dining Table
# 카테고리: furniture
# 스타일: tables
# 가격: $225.99
# 이벤트 타입: View
# 시간: 1597609245
# Item ID: be14695b-f8cb-46b8-aecd-ef28f0218514
# -------------------
# 아이템명: White Dining Table
# 카테고리: furniture
# 스타일: tables
# 가격: $225.99
# 이벤트 타입: View
# 시간: 1597607660
# Item ID: be14695b-f8cb-46b8-aecd-ef28f0218514
# -------------------
# 아이템명: White Dining Table
# 카테고리: furniture
# 스타일: tables
# 가격: $225.99
# 이벤트 타입: View
# 시간: 1597607660
# Item ID: be14695b-f8cb-46b8-aecd-ef28f0218514
# -------------------
# 아이템명: White Dining Table
# 카테고리: furniture
# 스타일: tables
# 가격: $225.99
# 이벤트 타입: View
# 시간: 1597607660
# Item ID: be14695b-f8cb-46b8-aecd-ef28f0218514
# -------------------
# 아이템명: Light Gray Dining Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $120.99
# 이벤트 타입: View
# 시간: 1597566756
# Item ID: 328a7f6b-238d-4165-9949-5e0aa70b7200
# -------------------
# 아이템명: Light Gray Dining Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $120.99
# 이벤트 타입: View
# 시간: 1597566756
# Item ID: 328a7f6b-238d-4165-9949-5e0aa70b7200
# -------------------
# 아이템명: Light Gray Dining Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $120.99
# 이벤트 타입: View
# 시간: 1597566756
# Item ID: 328a7f6b-238d-4165-9949-5e0aa70b7200
# -------------------
# 아이템명: Kettle
# 카테고리: housewares
# 스타일: kitchen
# 가격: $53.99
# 이벤트 타입: View
# 시간: 1597565859
# Item ID: aebf938b-e79b-48f3-a0b2-789f6e8f99f8
# -------------------
# 아이템명: Kettle
# 카테고리: housewares
# 스타일: kitchen
# 가격: $53.99
# 이벤트 타입: View
# 시간: 1597565856
# Item ID: aebf938b-e79b-48f3-a0b2-789f6e8f99f8
# -------------------
# 아이템명: Light Gray Dining Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $120.99
# 이벤트 타입: View
# 시간: 1597536146
# Item ID: 328a7f6b-238d-4165-9949-5e0aa70b7200
# -------------------
# 아이템명: Light Gray Dining Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $120.99
# 이벤트 타입: View
# 시간: 1597536145
# Item ID: 328a7f6b-238d-4165-9949-5e0aa70b7200
# -------------------
# 아이템명: Light Gray Dining Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $120.99
# 이벤트 타입: View
# 시간: 1597536145
# Item ID: 328a7f6b-238d-4165-9949-5e0aa70b7200
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1597378266
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1597378266
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1597378266
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: White Dining Table
# 카테고리: furniture
# 스타일: tables
# 가격: $225.99
# 이벤트 타입: View
# 시간: 1597353876
# Item ID: be14695b-f8cb-46b8-aecd-ef28f0218514
# -------------------
# 아이템명: White Dining Table
# 카테고리: furniture
# 스타일: tables
# 가격: $225.99
# 이벤트 타입: View
# 시간: 1597353876
# Item ID: be14695b-f8cb-46b8-aecd-ef28f0218514
# -------------------
# 아이템명: White Dining Table
# 카테고리: furniture
# 스타일: tables
# 가격: $225.99
# 이벤트 타입: View
# 시간: 1597353876
# Item ID: be14695b-f8cb-46b8-aecd-ef28f0218514
# -------------------
# 아이템명: Dark Gray Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $76.99
# 이벤트 타입: View
# 시간: 1597270723
# Item ID: b455a03d-a326-4d34-b45b-c2d44ae46dc6
# -------------------
# 아이템명: Dark Gray Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $76.99
# 이벤트 타입: View
# 시간: 1597270723
# Item ID: b455a03d-a326-4d34-b45b-c2d44ae46dc6
# -------------------
# 아이템명: Dark Gray Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $76.99
# 이벤트 타입: View
# 시간: 1597270723
# Item ID: b455a03d-a326-4d34-b45b-c2d44ae46dc6
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1597112728
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1597112728
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1597112728
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Teapot
# 카테고리: housewares
# 스타일: kitchen
# 가격: $58.99
# 이벤트 타입: View
# 시간: 1596509529
# Item ID: 7b20a8e1-5c56-41e9-aef3-1a4fd4637310
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1596491738
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1596491738
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1596491738
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Elegant Ceramic Bowl
# 카테고리: housewares
# 스타일: bowls
# 가격: $22.99
# 이벤트 타입: View
# 시간: 1596435896
# Item ID: 25e0f1af-8620-4eca-8573-4924d3fbee52
# -------------------
# 아이템명: Table Lamp
# 카테고리: homedecor
# 스타일: lighting
# 가격: $26.99
# 이벤트 타입: View
# 시간: 1596331732
# Item ID: 5763e87b-9b9c-456d-8986-1f1e34fa9318
# -------------------
# 아이템명: Ceramic Vase
# 카테고리: homedecor
# 스타일: decorative
# 가격: $33.99
# 이벤트 타입: View
# 시간: 1596311747
# Item ID: 1916e0ce-76ac-449b-aba0-4cef93a7824e
# -------------------
# 아이템명: Dark Gray Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $76.99
# 이벤트 타입: Purchase
# 시간: 1596148762
# Item ID: b455a03d-a326-4d34-b45b-c2d44ae46dc6
# -------------------
# 아이템명: Dark Gray Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $76.99
# 이벤트 타입: View
# 시간: 1596148751
# Item ID: b455a03d-a326-4d34-b45b-c2d44ae46dc6
# -------------------
# 아이템명: Dark Gray Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $76.99
# 이벤트 타입: View
# 시간: 1596148751
# Item ID: b455a03d-a326-4d34-b45b-c2d44ae46dc6
# -------------------
# 아이템명: Dark Gray Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $76.99
# 이벤트 타입: View
# 시간: 1596148751
# Item ID: b455a03d-a326-4d34-b45b-c2d44ae46dc6
# -------------------
# 아이템명: Saddle Brown Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $210.99
# 이벤트 타입: View
# 시간: 1596139001
# Item ID: 489dee3d-6abf-4470-bb94-8b9c0d12f18e
# -------------------
# 아이템명: Saddle Brown Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $210.99
# 이벤트 타입: View
# 시간: 1596139001
# Item ID: 489dee3d-6abf-4470-bb94-8b9c0d12f18e
# -------------------
# 아이템명: Saddle Brown Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $210.99
# 이벤트 타입: View
# 시간: 1596069695
# Item ID: 489dee3d-6abf-4470-bb94-8b9c0d12f18e
# -------------------
# 아이템명: Saddle Brown Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $210.99
# 이벤트 타입: View
# 시간: 1596069695
# Item ID: 489dee3d-6abf-4470-bb94-8b9c0d12f18e
# -------------------
# 아이템명: Saddle Brown Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $210.99
# 이벤트 타입: View
# 시간: 1595989918
# Item ID: 489dee3d-6abf-4470-bb94-8b9c0d12f18e
# -------------------
# 아이템명: Saddle Brown Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $210.99
# 이벤트 타입: View
# 시간: 1595989918
# Item ID: 489dee3d-6abf-4470-bb94-8b9c0d12f18e
# -------------------
# 아이템명: White Dining Table
# 카테고리: furniture
# 스타일: tables
# 가격: $225.99
# 이벤트 타입: View
# 시간: 1595852449
# Item ID: be14695b-f8cb-46b8-aecd-ef28f0218514
# -------------------
# 아이템명: White Dining Table
# 카테고리: furniture
# 스타일: tables
# 가격: $225.99
# 이벤트 타입: View
# 시간: 1595852449
# Item ID: be14695b-f8cb-46b8-aecd-ef28f0218514
# -------------------
# 아이템명: White Dining Table
# 카테고리: furniture
# 스타일: tables
# 가격: $225.99
# 이벤트 타입: View
# 시간: 1595852449
# Item ID: be14695b-f8cb-46b8-aecd-ef28f0218514
# -------------------
# 아이템명: Light Gray Dining Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $120.99
# 이벤트 타입: View
# 시간: 1595834328
# Item ID: 328a7f6b-238d-4165-9949-5e0aa70b7200
# -------------------
# 아이템명: Light Gray Dining Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $120.99
# 이벤트 타입: View
# 시간: 1595834328
# Item ID: 328a7f6b-238d-4165-9949-5e0aa70b7200
# -------------------
# 아이템명: Light Gray Dining Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $120.99
# 이벤트 타입: View
# 시간: 1595834328
# Item ID: 328a7f6b-238d-4165-9949-5e0aa70b7200
# -------------------
# 아이템명: Saddle Brown Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $210.99
# 이벤트 타입: View
# 시간: 1595558249
# Item ID: 489dee3d-6abf-4470-bb94-8b9c0d12f18e
# -------------------
# 아이템명: Saddle Brown Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $210.99
# 이벤트 타입: View
# 시간: 1595558249
# Item ID: 489dee3d-6abf-4470-bb94-8b9c0d12f18e
# -------------------
# 아이템명: Saddle Brown Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $210.99
# 이벤트 타입: View
# 시간: 1595558249
# Item ID: 489dee3d-6abf-4470-bb94-8b9c0d12f18e
# -------------------
# 아이템명: Elegant Ceramic Bowl
# 카테고리: housewares
# 스타일: bowls
# 가격: $22.99
# 이벤트 타입: View
# 시간: 1595514537
# Item ID: 25e0f1af-8620-4eca-8573-4924d3fbee52
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1595403299
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1595403299
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1595403299
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Light Gray Dining Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $120.99
# 이벤트 타입: View
# 시간: 1595370810
# Item ID: 328a7f6b-238d-4165-9949-5e0aa70b7200
# -------------------
# 아이템명: Light Gray Dining Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $120.99
# 이벤트 타입: View
# 시간: 1595370810
# Item ID: 328a7f6b-238d-4165-9949-5e0aa70b7200
# -------------------
# 아이템명: Light Gray Dining Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $120.99
# 이벤트 타입: View
# 시간: 1595370806
# Item ID: 328a7f6b-238d-4165-9949-5e0aa70b7200
# -------------------
# 아이템명: Floral Design Plates
# 카테고리: housewares
# 스타일: kitchen
# 가격: $58.99
# 이벤트 타입: View
# 시간: 1595342164
# Item ID: 5c0b070b-3bf1-4d2b-99a7-0906b90ca28f
# -------------------
# 아이템명: Ceramic Vase
# 카테고리: homedecor
# 스타일: decorative
# 가격: $33.99
# 이벤트 타입: View
# 시간: 1595291553
# Item ID: 1916e0ce-76ac-449b-aba0-4cef93a7824e
# -------------------
# 아이템명: Table Lamp
# 카테고리: homedecor
# 스타일: lighting
# 가격: $26.99
# 이벤트 타입: View
# 시간: 1595279461
# Item ID: 5763e87b-9b9c-456d-8986-1f1e34fa9318
# -------------------
# 아이템명: Saddle Brown Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $210.99
# 이벤트 타입: View
# 시간: 1594976812
# Item ID: 489dee3d-6abf-4470-bb94-8b9c0d12f18e
# -------------------
# 아이템명: Saddle Brown Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $210.99
# 이벤트 타입: View
# 시간: 1594976812
# Item ID: 489dee3d-6abf-4470-bb94-8b9c0d12f18e
# -------------------
# 아이템명: Saddle Brown Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $210.99
# 이벤트 타입: View
# 시간: 1594976812
# Item ID: 489dee3d-6abf-4470-bb94-8b9c0d12f18e
# -------------------
# 아이템명: Easter Basket
# 카테고리: homedecor
# 스타일: decorative
# 가격: $18.99
# 이벤트 타입: View
# 시간: 1594966253
# Item ID: 6f3a269d-f83f-4659-a28e-7ddbbcea4eab
# -------------------
# 아이템명: Easter Basket
# 카테고리: homedecor
# 스타일: decorative
# 가격: $18.99
# 이벤트 타입: View
# 시간: 1594966253
# Item ID: 6f3a269d-f83f-4659-a28e-7ddbbcea4eab
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1594725409
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1594725409
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1594725409
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Elegant Ceramic Bowl
# 카테고리: housewares
# 스타일: bowls
# 가격: $22.99
# 이벤트 타입: View
# 시간: 1594573917
# Item ID: 25e0f1af-8620-4eca-8573-4924d3fbee52
# -------------------
# 아이템명: Pots Set
# 카테고리: housewares
# 스타일: kitchen
# 가격: $58.99
# 이벤트 타입: View
# 시간: 1594538396
# Item ID: 35efa417-357d-465e-99cb-b208bbc63f8b
# -------------------
# 아이템명: White Dining Table
# 카테고리: furniture
# 스타일: tables
# 가격: $225.99
# 이벤트 타입: View
# 시간: 1594501613
# Item ID: be14695b-f8cb-46b8-aecd-ef28f0218514
# -------------------
# 아이템명: White Dining Table
# 카테고리: furniture
# 스타일: tables
# 가격: $225.99
# 이벤트 타입: View
# 시간: 1594501613
# Item ID: be14695b-f8cb-46b8-aecd-ef28f0218514
# -------------------
# 아이템명: White Dining Table
# 카테고리: furniture
# 스타일: tables
# 가격: $225.99
# 이벤트 타입: View
# 시간: 1594501613
# Item ID: be14695b-f8cb-46b8-aecd-ef28f0218514
# -------------------
# 아이템명: Dark Gray Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $76.99
# 이벤트 타입: View
# 시간: 1594443188
# Item ID: b455a03d-a326-4d34-b45b-c2d44ae46dc6
# -------------------
# 아이템명: Dark Gray Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $76.99
# 이벤트 타입: View
# 시간: 1594443188
# Item ID: b455a03d-a326-4d34-b45b-c2d44ae46dc6
# -------------------
# 아이템명: Dark Gray Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $76.99
# 이벤트 타입: View
# 시간: 1594443188
# Item ID: b455a03d-a326-4d34-b45b-c2d44ae46dc6
# -------------------
# 아이템명: Saddle Brown Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $210.99
# 이벤트 타입: View
# 시간: 1594420070
# Item ID: 489dee3d-6abf-4470-bb94-8b9c0d12f18e
# -------------------
# 아이템명: Saddle Brown Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $210.99
# 이벤트 타입: View
# 시간: 1594420070
# Item ID: 489dee3d-6abf-4470-bb94-8b9c0d12f18e
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1594354295
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1594354295
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1594354295
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1594029443
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1594029443
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1594029443
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Floral Design Plates
# 카테고리: housewares
# 스타일: kitchen
# 가격: $58.99
# 이벤트 타입: View
# 시간: 1593896678
# Item ID: 5c0b070b-3bf1-4d2b-99a7-0906b90ca28f
# -------------------
# 아이템명: Ceramic Vase
# 카테고리: homedecor
# 스타일: decorative
# 가격: $15.99
# 이벤트 타입: View
# 시간: 1593882624
# Item ID: 81eee14d-d22e-43a2-8110-b610b6eaafd1
# -------------------
# 아이템명: Ceramic Vase
# 카테고리: homedecor
# 스타일: decorative
# 가격: $15.99
# 이벤트 타입: View
# 시간: 1593882624
# Item ID: 81eee14d-d22e-43a2-8110-b610b6eaafd1
# -------------------
# 아이템명: Easter Basket
# 카테고리: homedecor
# 스타일: decorative
# 가격: $18.99
# 이벤트 타입: View
# 시간: 1593829500
# Item ID: 6f3a269d-f83f-4659-a28e-7ddbbcea4eab
# -------------------
# 아이템명: Easter Basket
# 카테고리: homedecor
# 스타일: decorative
# 가격: $18.99
# 이벤트 타입: View
# 시간: 1593829500
# Item ID: 6f3a269d-f83f-4659-a28e-7ddbbcea4eab
# -------------------
# 아이템명: Dark Gray Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $76.99
# 이벤트 타입: View
# 시간: 1593636954
# Item ID: b455a03d-a326-4d34-b45b-c2d44ae46dc6
# -------------------
# 아이템명: Dark Gray Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $76.99
# 이벤트 타입: View
# 시간: 1593636954
# Item ID: b455a03d-a326-4d34-b45b-c2d44ae46dc6
# -------------------
# 아이템명: Dark Gray Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $76.99
# 이벤트 타입: View
# 시간: 1593636954
# Item ID: b455a03d-a326-4d34-b45b-c2d44ae46dc6
# -------------------
# 아이템명: Table Lamp
# 카테고리: homedecor
# 스타일: lighting
# 가격: $26.99
# 이벤트 타입: View
# 시간: 1593390941
# Item ID: 5763e87b-9b9c-456d-8986-1f1e34fa9318
# -------------------
# 아이템명: Table Lamp
# 카테고리: homedecor
# 스타일: lighting
# 가격: $26.99
# 이벤트 타입: View
# 시간: 1593390939
# Item ID: 5763e87b-9b9c-456d-8986-1f1e34fa9318
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1593375019
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1593375019
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Light Gray Dining Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $120.99
# 이벤트 타입: View
# 시간: 1593342594
# Item ID: 328a7f6b-238d-4165-9949-5e0aa70b7200
# -------------------
# 아이템명: Light Gray Dining Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $120.99
# 이벤트 타입: View
# 시간: 1593342594
# Item ID: 328a7f6b-238d-4165-9949-5e0aa70b7200
# -------------------
# 아이템명: Light Gray Dining Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $120.99
# 이벤트 타입: View
# 시간: 1593342594
# Item ID: 328a7f6b-238d-4165-9949-5e0aa70b7200
# -------------------
# 아이템명: Table Lamp
# 카테고리: homedecor
# 스타일: lighting
# 가격: $26.99
# 이벤트 타입: View
# 시간: 1593112358
# Item ID: 5763e87b-9b9c-456d-8986-1f1e34fa9318
# -------------------
# 아이템명: Table Lamp
# 카테고리: homedecor
# 스타일: lighting
# 가격: $26.99
# 이벤트 타입: View
# 시간: 1593112358
# Item ID: 5763e87b-9b9c-456d-8986-1f1e34fa9318
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1593002916
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1593002916
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1593002916
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1592959359
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1592959359
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1592959359
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1592938905
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1592938905
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: Black Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $205.99
# 이벤트 타입: View
# 시간: 1592938905
# Item ID: 079ab14b-3435-4a95-ba1d-fc0b21e0cf4b
# -------------------
# 아이템명: White Dining Table
# 카테고리: furniture
# 스타일: tables
# 가격: $225.99
# 이벤트 타입: View
# 시간: 1592840681
# Item ID: be14695b-f8cb-46b8-aecd-ef28f0218514
# -------------------
# 아이템명: White Dining Table
# 카테고리: furniture
# 스타일: tables
# 가격: $225.99
# 이벤트 타입: View
# 시간: 1592840681
# Item ID: be14695b-f8cb-46b8-aecd-ef28f0218514
# -------------------
# 아이템명: Teapot
# 카테고리: housewares
# 스타일: kitchen
# 가격: $58.99
# 이벤트 타입: View
# 시간: 1592781569
# Item ID: 7b20a8e1-5c56-41e9-aef3-1a4fd4637310
# -------------------
# 아이템명: Saddle Brown Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $210.99
# 이벤트 타입: View
# 시간: 1592634650
# Item ID: 489dee3d-6abf-4470-bb94-8b9c0d12f18e
# -------------------
# 아이템명: Saddle Brown Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $210.99
# 이벤트 타입: View
# 시간: 1592634650
# Item ID: 489dee3d-6abf-4470-bb94-8b9c0d12f18e
# -------------------
# 아이템명: Saddle Brown Office Chair
# 카테고리: furniture
# 스타일: chairs
# 가격: $210.99
# 이벤트 타입: View
# 시간: 1592634650
# Item ID: 489dee3d-6abf-4470-bb94-8b9c0d12f18e
# -------------------
# 아이템명: Ceramic Vase
# 카테고리: homedecor
# 스타일: decorative
# 가격: $33.99
# 이벤트 타입: View
# 시간: 1592598901
# Item ID: 1916e0ce-76ac-449b-aba0-4cef93a7824e
# -------------------
# 아이템명: Ceramic Vase
# 카테고리: homedecor
# 스타일: decorative
# 가격: $33.99
# 이벤트 타입: View
# 시간: 1592598901
# Item ID: 1916e0ce-76ac-449b-aba0-4cef93a7824e
# -------------------
# 아이템명: Pots Set
# 카테고리: housewares
# 스타일: kitchen
# 가격: $58.99
# 이벤트 타입: View
# 시간: 1592007327
# Item ID: 35efa417-357d-465e-99cb-b208bbc63f8b
# -------------------
# 아이템명: Pots Set
# 카테고리: housewares
# 스타일: kitchen
# 가격: $58.99
# 이벤트 타입: View
# 시간: 1592007327
# Item ID: 35efa417-357d-465e-99cb-b208bbc63f8b

# %% [markdown]
# ### USER-PERSONALIZATION 솔루션 추천 : user_id = 1

# %%
user_id = 1

get_recommendations_response = personalize_runtime.get_recommendations(
    campaignArn = base_campaign_arn,
    userId = str(user_id),
    numResults = 10
)


items_list = []    
for item in get_recommendations_response['itemList']:
    items_list.append(item['itemId'])   
    # print (item['itemId'])
    
print("-------------------")    
print("user_id: ", user_id)    
print("-------------------")    
print("Solution Recommendation")
get_item_list_details(items_df, items_list)  # 유의: 기존의 추천 순서와 리턴의 값이 순서가 다름
# Out:
# -------------------
# user_id:  1
# -------------------
# Solution Recommendation
#                                 ITEM_ID                     NAME CATEGORY_L1  \
# 0  557bb55d-3cac-4c5c-bb30-1d66bc60e8ae    Rosy-Brown Work Table   furniture
# 1  5763e87b-9b9c-456d-8986-1f1e34fa9318               Table Lamp   homedecor
# 2  328a7f6b-238d-4165-9949-5e0aa70b7200  Light Gray Dining Chair   furniture
# 3  96d887df-efe3-4d05-8df0-8cb2a0674711               Jar Candle   homedecor
# 4  c54d3f55-35b8-47c6-9771-a573aa00f4ad        Peru-Orange Chair   furniture
# 5  c8312844-248a-4a07-96a1-4c02cb1e2471         Tan Dining Table   furniture
# 6  3ef07621-8af8-42c5-891b-94f403787fd7          Gray Work Table   furniture
# 7  d055f31f-2e3e-4338-ac64-521f88779b50      Dark Gray Worktable   furniture
# 8  9747c3ce-b89d-4992-bf3d-f4ecc5a668fe   Dark Gray Office Chair   furniture
# 9  ff47435d-97d2-4d05-b3e8-294d4c47cbc3      Dark Gray Worktable   furniture
#
#       STYLE                                PRODUCT_DESCRIPTION   PRICE
# 0    tables  Increase your productivity with this outstandi...  188.99
# 1  lighting             This table lamp will enhance your home   26.99
# 2    chairs  Unparalleled light gray chair for any dining room  120.99
# 3  lighting             This jar candle will enhance your home   40.99
# 4    chairs           Enjoy this soft peru-orange dining chair  146.99
# 5    tables  This definitive tan dining table will delight ...  169.99
# 6    tables  Increase your productivity with this outstandi...  222.99
# 7    tables    Unsurpassed dark gray worktable for your office  178.99
# 8    chairs        Unsurpassed dark gray chair for your office  211.99
# 9    tables      Unrivaled dark gray worktable for your office  212.99

# %% [markdown]
# ### USER-PERSONALIZATION 솔루션 추천 : user_id = 100

# %%
user_id = 100

get_recommendations_response = personalize_runtime.get_recommendations(
    campaignArn = base_campaign_arn,
    userId = str(user_id),
    numResults = 10
)


items_list = []    
for item in get_recommendations_response['itemList']:
    items_list.append(item['itemId'])   
    # print (item['itemId'])
    
print("-------------------")    
print("user_id: ", user_id)    
print("-------------------")    
print("Solution Recommendation")
get_item_list_details(items_df, items_list)  # 유의: 기존의 추천 순서와 리턴의 값이 순서가 다름
# Out:
# -------------------
# user_id:  100
# -------------------
# Solution Recommendation
#                                 ITEM_ID                 NAME  CATEGORY_L1  \
# 0  6ca2a410-aba9-4c73-9dae-d188412e0e50      Electric Guitar  instruments
# 1  387f55e6-0eb9-47d6-9ef1-56a80b884430        Electric Bass  instruments
# 2  e09d3267-1a87-4518-9fa7-fa9ed847c80d  Accurate Microphone  instruments
# 3  76fa669b-1611-4f31-8377-55c3e701ced4            Saxophone  instruments
# 4  ab5ea156-d41d-43bc-ae5f-10b47f8e42f1        Acoustic Bass  instruments
# 5  93a1db77-615e-49aa-9f1e-edcf7c6675f4               Violin  instruments
# 6  a54fbc82-c85d-4d21-b907-e8cdbbff69d2        Acoustic Bass  instruments
# 7  24a19516-a629-4703-af46-cf28f604a48a      Electric Guitar  instruments
# 8  51fd504d-ca0a-422b-8cb4-0ca97b35b830      Acoustic Guitar  instruments
# 9  97b25afe-68ca-445d-a276-dc7e09df575d        Upright Piano  instruments
#
#         STYLE                                PRODUCT_DESCRIPTION   PRICE
# 0     strings  This electric guitar will delight the most dem...  114.99
# 1     strings  This electric bass will delight the most deman...   57.99
# 2  microphone  This accurate microphone can be relied upon in...  499.99
# 3        wind  This saxophone is perfect for amateur and prof...   95.99
# 4     strings  This acoustic bass is perfect for amateur and ...  187.99
# 5     strings  This violin is perfect for amateur and profess...   77.99
# 6     strings  This acoustic bass will delight the most deman...  221.99
# 7     strings  This electric guitar is perfect for amateur an...   99.99
# 8     strings  This acoustic guitar is perfect for amateur an...  150.99
# 9        keys  This upright piano will delight the most deman...  184.99
