# %% [markdown]
# # [Module 8] Recommendation API 호출

# %% [markdown]
# # 0. 환경 설정

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import boto3
import json
import numpy as np
import pandas as pd
import time
from datetime import datetime

# %% [markdown]
# 다음으로 여러분의 환경이 Amazon Personalize와 성공적으로 통신할 수 있는지 확인해야 합니다.

# %%
# Configure the SDK to Personalize:
personalize = boto3.client('personalize')
personalize_runtime = boto3.client('personalize-runtime')

# %% [markdown]
# 아래 코드 셀은 이전 notebook에서 저장했던 공유 변수들을 불러옵니다.

# %%
# %store -r

# %% [markdown]
# # 1. 아이템 테이터 로딩
#
# - 추천 결과의 ITEM_ID 의 상세 내용을 확인하기 위해서 로딩 함.

# %%
from src.p_utils import get_item_list_details

items_df = pd.read_csv(base_items_filename)

items_df.head()
# Out:
#                                 ITEM_ID                      NAME  \
# 0  e1669081-8ffc-4dec-97a6-e9176d7f6651         Sans Pareil Scarf
# 1  cfafd627-7d6b-43a5-be05-4c7937be417d                Chef Knife
# 2  6e6ad102-7510-4a02-b8ce-5a0cd6f431d1          Gainsboro Jacket
# 3  49b89871-5fe7-4898-b99d-953e15fb42b2  High Definition Speakers
# 4  5cb18925-3a3c-4867-8f1c-46efd7eba067            Spiffy Sandals
#
#    CATEGORY_L1    STYLE                                PRODUCT_DESCRIPTION  \
# 0      apparel    scarf                        Sans pareil scarf for women
# 1   housewares  kitchen                       A must-have for your kitchen
# 2      apparel   jacket  This gainsboro jacket for women is perfect for...
# 3  electronics  speaker  High definition speakers to fill the house wit...
# 4     footwear  sandals  This spiffy pair of sandals for woman is perfe...
#
#     PRICE
# 0  124.99
# 1   57.99
# 2  133.99
# 3  196.99
# 4    9.99

# %% [markdown]
# # 2. Recommendation API 호출
#
# - 두 명의 user_id (에: 1, 100) 에 대해서 추천 결과를 얻음.

# %% [markdown]
# ### USER-PERSONALIZATION 솔루션 추천 : user_id = 1

# %%
user_id = 1

get_recommendations_response = personalize_runtime.get_recommendations(
    campaignArn = base_campaign_arn,
    userId = str(user_id),
    numResults = 10
)


items_list = []    
for item in get_recommendations_response['itemList']:
    items_list.append(item['itemId'])   
    # print (item['itemId'])
    
print("-------------------")    
print("user_id: ", user_id)    
print("-------------------")    
print("Solution Recommendation")
get_item_list_details(items_df, items_list)  # 유의: 기존의 추천 순서와 리턴의 값이 순서가 다름
# Out:
# -------------------
# user_id:  1
# -------------------
# Solution Recommendation
#                                 ITEM_ID                NAME CATEGORY_L1  \
# 0  2ab5209d-519d-41ed-a57d-4e67569cad0e          Jar Candle   homedecor
# 1  5763e87b-9b9c-456d-8986-1f1e34fa9318          Table Lamp   homedecor
# 2  2ffa8784-9c55-414e-b852-b0615a49bfb9       Pillar Candle   homedecor
# 3  f115c9be-eae6-4bdf-9b92-32ba579a43b1  Black Office Chair   furniture
# 4  48941756-e6c4-4b45-a869-c4f33daccdeb     Yellow Armchair   furniture
# 5  f90602f6-d516-44f2-84d4-49d3058892bb          Table Lamp   homedecor
# 6  eb46bfcc-34df-40e2-8670-ee808d5cb958  Black Dining Chair   furniture
# 7  a54ad1ab-3312-4c36-82e6-2b20b97bc68c        Hanging Lamp   homedecor
# 8  6685cdbb-07c0-448d-9927-a5477e610363        Ceramic Vase   homedecor
# 9  cb96fbf3-b884-4c21-8e6c-8281773c0ebc        Hanging Lamp   homedecor
#
#         STYLE                                PRODUCT_DESCRIPTION   PRICE
# 0    lighting             This jar candle will enhance your home   40.99
# 1    lighting             This table lamp will enhance your home   26.99
# 2    lighting          This pillar candle will enhance your home   35.99
# 3      chairs  Increase your productivity with this comfy bla...  208.99
# 4      chairs                 Relax in this nice yellow armchair  111.99
# 5    lighting             This table lamp will enhance your home   47.99
# 6      chairs       Incomparable black chair for any dining room  125.99
# 7    lighting           This hanging lamp will enhance your home   51.99
# 8  decorative  This ceramic vase is a must-have for your home...   33.99
# 9    lighting           This hanging lamp will enhance your home   20.99

# %% [markdown]
# ### USER-PERSONALIZATION 솔루션 추천 : user_id = 100

# %%
user_id = 100

get_recommendations_response = personalize_runtime.get_recommendations(
    campaignArn = base_campaign_arn,
    userId = str(user_id),
    numResults = 10
)


items_list = []    
for item in get_recommendations_response['itemList']:
    items_list.append(item['itemId'])   
    # print (item['itemId'])
    
print("-------------------")    
print("user_id: ", user_id)    
print("-------------------")    
print("Solution Recommendation")
get_item_list_details(items_df, items_list)  # 유의: 기존의 추천 순서와 리턴의 값이 순서가 다름
# Out:
# -------------------
# user_id:  100
# -------------------
# Solution Recommendation
#                                 ITEM_ID                 NAME  CATEGORY_L1  \
# 0  387f55e6-0eb9-47d6-9ef1-56a80b884430        Electric Bass  instruments
# 1  6ca2a410-aba9-4c73-9dae-d188412e0e50      Electric Guitar  instruments
# 2  e09d3267-1a87-4518-9fa7-fa9ed847c80d  Accurate Microphone  instruments
# 3  66725b05-5d69-48f5-bafc-883957a493d1          French Horn  instruments
# 4  24a19516-a629-4703-af46-cf28f604a48a      Electric Guitar  instruments
# 5  76fa669b-1611-4f31-8377-55c3e701ced4            Saxophone  instruments
# 6  5dd5e235-4d2e-432b-a1b9-8e738dc8aa3a     Desktop Computer  electronics
# 7  168cc760-2d97-4a6e-9cf6-515996151b1d          Grand Piano  instruments
# 8  4f456260-d3eb-4376-a2ac-58180f3446e7        Acoustic Drum  instruments
# 9  bae78d39-8f13-4497-839e-9dba87583b93              Trumpet  instruments
#
#         STYLE                                PRODUCT_DESCRIPTION   PRICE
# 0     strings  This electric bass will delight the most deman...   57.99
# 1     strings  This electric guitar will delight the most dem...  114.99
# 2  microphone  This accurate microphone can be relied upon in...  499.99
# 3        wind  This french horn is perfect for amateur and pr...  192.99
# 4     strings  This electric guitar is perfect for amateur an...   99.99
# 5        wind  This saxophone is perfect for amateur and prof...   95.99
# 6    computer          Desktop computer for your computing needs    9.99
# 7        keys  This grand piano will delight the most demandi...  198.99
# 8  percussion  This acoustic drum is perfect for amateur and ...  150.99
# 9        wind  This trumpet is perfect for amateur and profes...  108.99
